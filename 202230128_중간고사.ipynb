# %%
import pandas as pd

data = pd.read_csv("C:/Users/user/Downloads/integrated_student_data.csv")

df = pd.DataFrame(data)
print(df)
# Out:
#    student_id          name                   email  study_hours  attendance  \
# 0         B01    Kim Hana     HANA.KIM@DAELIM.AC.KR          1.5          55
# 1         B02       Lee Min   lee.min@daelim.ac.kr           2.0          62
# 2         B03      Park Jun      park.jun@email.com          2.5          68
# 3         B04      Choi Seo   CHOI.SEO@DAELIM.AC.KR          3.0          72
# 4         B05      Jung Woo   jung.woo@daelim.ac.kr          3.5          74
# 5         B06      Kang Yul   kang.yul@daelim.ac.kr          4.0          78
# 6         B07      Song Ara   song.ara@daelim.ac.kr          4.5          80
# 7         B08      Yoon Sol      yoon.sol@email.com          5.0          83
# 8         B09       Han Bin    HAN.BIN@DAELIM.AC.KR          5.5          86
# 9         B10       Lim Jae    lim.jae@daelim.ac.kr          6.0          88
# 10        B11       Oh Nuri    oh.nuri@daelim.ac.kr          6.5          91
# ...

# %%
import pandas as pd
df = pd.read_csv("C:/Users/user/Downloads/integrated_student_data.csv")
df['name'] = df['name'].str.strip()
df['email'] = df['email'].str.strip().str.lower()
df['domain'] = df['email'].where(df['email'].str.contains('@')).str.split('@').str[1]

print(df)
# Out:
#    student_id      name                  email  study_hours  attendance  \
# 0         B01  Kim Hana  hana.kim@daelim.ac.kr          1.5          55
# 1         B02   Lee Min   lee.min@daelim.ac.kr          2.0          62
# 2         B03  Park Jun     park.jun@email.com          2.5          68
# 3         B04  Choi Seo  choi.seo@daelim.ac.kr          3.0          72
# 4         B05  Jung Woo  jung.woo@daelim.ac.kr          3.5          74
# 5         B06  Kang Yul  kang.yul@daelim.ac.kr          4.0          78
# 6         B07  Song Ara  song.ara@daelim.ac.kr          4.5          80
# 7         B08  Yoon Sol     yoon.sol@email.com          5.0          83
# 8         B09   Han Bin   han.bin@daelim.ac.kr          5.5          86
# 9         B10   Lim Jae   lim.jae@daelim.ac.kr          6.0          88
# 10        B11   Oh Nuri   oh.nuri@daelim.ac.kr          6.5          91
# 11        B12  Moon Rae  moon.rae@daelim.ac.kr          7.0          94
# ...

# %%
# %pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt
import matplotlib
import platform

if platform.system() == "Window":
    matplotlib.rc("font", family = "Malgun Gothic")
elif platform.system() == "Darwin":
    matplotlib.rc("font", family = "AppleGothic")
else:
    matplotlib.rc("font", family = "Malgun Gothic")

matplotlib.rc("axes", unicode_minus=False)

print("matplotlib 준비 완료")
print("현재 OS:", platform.system())
# Out:
# matplotlib 준비 완료
# 현재 OS: Windows

# %%
plt.figure(figsize=(10, 5))
plt.plot(, , marker="o", color="orange")
plt.title("주차별 실습 제출률 변화")
plt.xlabel("주차")
plt.ylabel("제출률(%)")
plt.text(0, , ha="center")
plt.grid(True)
plt.show()
# Out:
#   Cell In[41], line 2
#     plt.plot(, , marker="o", color="orange")
#              ^
# SyntaxError: invalid syntax

# %%
new_student = pd.DataFrame([
    [2.0, 75, 60, 58, 62],
    [4.0, 72, 80, 76, 78],
    [5.5,88,86,85,87],
    [3.0,60,88,72,75]
],columns=["study_hours","attendance","assignment_score","quiz_avg","project_score"])


pass_study = [study_hours[i] for i in range(len(pass_fail)) if pass_fail[i] == 1]
pass_score = [assignment_score[i] for i in range(len(pass_fail)) if pass_fail[i] == 1]
fail_study = [study[i] for i in range(len(pass_fail)) if pass_fail[i] == 0]
fail_score = [score[i] for i in range(len(pass_fail)) if pass_fail[i] == 0]

plt.figure(figsize=(8,5))
plt.scatter(pass_study, pass_score, color="steelblue", s=70, label="합격")
plt.scatter(fail_study, fail_score, color="tomato", s=70, label="불합격")
plt.title("출석률과 종합점수에 따른 합격 여부")
plt.xlabel("출석률(%)")
plt.ylabel("종합점수")
plt.ylim(0, 100)
plt.legend()
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 new_student = pd.DataFrame([
#       2     [2.0, 75, 60, 58, 62],
#       3     [4.0, 72, 80, 76, 78],
#       4     [5.5,88,86,85,87],
#       5     [3.0,60,88,72,75]
#       6 ],columns=["study_hours","attendance","assignment_score","quiz_avg","project_score"])
#       9 pass_study = [study_hours[i] for i in range(len(pass_fail)) if pass_fail[i] == 1]
#      10 pass_score = [assignment_score[i] for i in range(len(pass_fail)) if pass_fail[i] == 1]
#
# NameError: name 'pd' is not defined
